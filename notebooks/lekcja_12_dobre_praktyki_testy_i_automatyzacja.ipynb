# %% [markdown]
# # Lekcja 12: Dobre praktyki — testy, logowanie i automatyzacja
#
# Cel: utrzymywać jakość kodu analitycznego i API.

# %% [markdown]
# ## Zakres
# - pytest dla funkcji danych
# - logging
# - harmonogram uruchomień (cron / GitHub Actions)

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Pipeline zakończony powodzeniem")
