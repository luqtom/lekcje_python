# %% [markdown]
# # Lekcja 1: Wprowadzenie do Pythona pod API i analizę danych
#
# W tej lekcji przygotujesz fundament do pracy z danymi: typy, struktury, operacje i środowisko.

# %% [markdown]
# ## Cele lekcji
# - podstawowe typy danych
# - listy i słowniki
# - przygotowanie środowiska

# %%
imie="Ania"
wiek=22
ocena=4.75
aktywny=True
print(type(imie), type(wiek), type(ocena), type(aktywny))

# %%
uzytkownik={"id":101,"name":"Anna Kowalska","roles":["student","analityk"]}
print(uzytkownik["name"])
print(len(uzytkownik["roles"]))

# %%
wartosci=[10,12,15,9,14]
print(round(sum(wartosci)/len(wartosci),2))

# %% [markdown]
# ## Środowisko
# ```bash
# python -m venv .venv
# source .venv/bin/activate
# pip install requests pandas matplotlib seaborn
# ```

# %% [markdown]
# ## Zadanie
# Utwórz słownik produktu i policz cenę brutto.
