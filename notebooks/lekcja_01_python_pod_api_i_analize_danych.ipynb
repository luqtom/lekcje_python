# %% [markdown]
# # Lekcja 1: Wprowadzenie do Pythona pod API i analizę danych
#
# Cel: przygotować środowisko i poznać podstawy potrzebne do pracy z danymi.

# %% [markdown]
# ## Zakres
# - typy danych i struktury
# - podstawowe operacje na tekstach i liczbach
# - szybkie przygotowanie środowiska (venv, pip)

# %%
dane = {"status": "ok", "rekordy": 3}
print(f"Status: {dane['status']}, rekordy: {dane['rekordy']}")
