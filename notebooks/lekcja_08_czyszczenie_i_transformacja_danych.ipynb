# %% [markdown]
# # Lekcja 8: Czyszczenie i transformacja danych
#
# Cel: przygotować dane do raportowania i modeli.

# %% [markdown]
# ## Zakres
# - brakujące wartości
# - konwersja typów
# - tworzenie nowych kolumn

# %%
import pandas as pd

df = pd.DataFrame({"cena": [10.0, None, 30.5]})
df["cena"] = df["cena"].fillna(df["cena"].mean())
print(df)
