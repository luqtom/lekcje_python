# %% [markdown]
# # Lekcja 2: Funkcje i moduły w praktyce danych
#
# Cel: pisać czytelny kod wielokrotnego użytku.

# %% [markdown]
# ## Zakres
# - definiowanie funkcji
# - importy i moduły
# - proste utility do czyszczenia danych

# %%
def normalizuj_nazwe(nazwa: str) -> str:
    return nazwa.strip().lower()

print(normalizuj_nazwe("  API Users  "))
