# %% [markdown]
# # Lekcja 5: API — paginacja, filtrowanie i parametry zapytań
#
# Cel: pobierać większe zbiory danych etapami.

# %% [markdown]
# ## Zakres
# - params w requests
# - paginacja offset/limit
# - filtrowanie danych po stronie klienta

# %%
parametry = {"page": 1, "limit": 20, "sort": "date"}
print(parametry)
