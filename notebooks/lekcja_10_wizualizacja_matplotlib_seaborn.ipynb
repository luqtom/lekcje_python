# %% [markdown]
# # Lekcja 10: Wizualizacja danych — matplotlib i seaborn
#
# Cel: tworzyć czytelne wykresy dla raportów.

# %% [markdown]
# ## Zakres
# - wykres liniowy i słupkowy
# - histogram
# - estetyka wykresów

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 4, 3]
plt.plot(x, y)
plt.title("Przykładowy trend")
plt.show()
