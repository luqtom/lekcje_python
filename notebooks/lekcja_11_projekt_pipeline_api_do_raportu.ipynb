# %% [markdown]
# # Lekcja 11: Projekt — pipeline od API do raportu
#
# Cel: zbudować kompletny przepływ danych.

# %% [markdown]
# ## Zakres
# - pobranie danych z API
# - transformacja w pandas
# - eksport raportu CSV/Excel

# %%
kroki = ["pobierz", "oczyść", "analizuj", "raportuj"]
for k in kroki:
    print(f"Krok: {k}")
