# %% [markdown]
# # Lekcja 7: Pandas — podstawy analizy tabelarycznej
#
# Cel: szybko analizować dane w DataFrame.

# %% [markdown]
# ## Zakres
# - tworzenie DataFrame
# - selekcja kolumn i wierszy
# - podstawowe statystyki

# %%
import pandas as pd

df = pd.DataFrame({"miasto": ["Warszawa", "Gdańsk"], "sprzedaż": [120, 95]})
print(df.describe(include="all"))
