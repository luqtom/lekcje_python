# %% [markdown]
# # Lekcja 3: Praca z plikami CSV i JSON
#
# Cel: wczytywać i zapisywać dane w popularnych formatach.

# %% [markdown]
# ## Zakres
# - csv i json z biblioteki standardowej
# - serializacja i deserializacja
# - walidacja podstawowych pól

# %%
import json
rekord = {"id": 1, "miasto": "Kraków"}
print(json.dumps(rekord, ensure_ascii=False))
