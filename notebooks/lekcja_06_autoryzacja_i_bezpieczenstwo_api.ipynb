# %% [markdown]
# # Lekcja 6: Autoryzacja i bezpieczeństwo w API
#
# Cel: bezpiecznie korzystać z kluczy i tokenów.

# %% [markdown]
# ## Zakres
# - API key i Bearer token
# - zmienne środowiskowe
# - podstawy rate limiting

# %%
import os
TOKEN = os.getenv("API_TOKEN", "BRAK_TOKENU")
print("Token ustawiony:", TOKEN != "BRAK_TOKENU")
